# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(df.index,df['sepal.width'])

# %%
sns.scatterplot(x=df.index,y=df['sepal.width'],hue=df['variety'])
# Out:
# <AxesSubplot:ylabel='sepal.width'>

# %%
# Strip-plot 
#sirve para cuando una variable es categorica
sns.stripplot(x=df['variety'],y=df['sepal.width'])
# Out:
# <AxesSubplot:xlabel='variety', ylabel='sepal.width'>

# %%
#Swarm plot
#los puntos no estan solapados
#Swarm-plot category wise
sns.swarmplot(x=df['variety'],y=df['sepal.width'])
# Out:
# <AxesSubplot:xlabel='variety', ylabel='sepal.width'>

# %%
#Summary plots

sns.histplot(df['petal.width'],kde=False,color='black',bins=10)
# Out:
# <AxesSubplot:xlabel='petal.width', ylabel='Count'>

# %%
#parecido a un histogrampa pero fitea una funcion de densidad
#jkernel density estimation
sns.set(rc={'figure.figsize':(5,5)})
sns.kdeplot(df['petal.length'],shade=True)
# Out:
# <AxesSubplot:xlabel='petal.length', ylabel='Density'>

# %%
dfM=df.drop('variety',axis=1)
sns.set(rc={'figure.figsize':(9,9)})
sns.boxplot(x="variable", y="value", data=pd.melt(dfM))
# Out:
# <AxesSubplot:xlabel='variable', ylabel='value'>

# %%
plt.figure(figsize=(7,7))
plt.violinplot(dfM.values,showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f8915b71160>,
#   <matplotlib.collections.PolyCollection at 0x7f8915b71490>,
#   <matplotlib.collections.PolyCollection at 0x7f8915b717c0>,
#   <matplotlib.collections.PolyCollection at 0x7f8915b71af0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f8915be2fd0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f8915b7e0a0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f8915b7e460>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x7f8915b7e820>}

# %%
sns.set(rc={'figure.figsize':(9,9)})
sns.violinplot(x=df['variety'], y=df['petal.width'],data=df)
# Out:
# <AxesSubplot:xlabel='variety', ylabel='petal.width'>

# %%
sns.countplot(x=df['variety'])
# Out:
# <AxesSubplot:xlabel='variety', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='variety', ylabel='count'>
