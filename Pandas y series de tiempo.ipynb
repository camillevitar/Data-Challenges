# %%
#importamos las librerias
import numpy as np
import pandas as pd

# %%
#Importando la base de datos
df = pd.read_csv('C:/Users/k1000/Desktop/Data/Summer-Olympic-medals-1976-to-2008.csv')

# %%
df.head()
# Out:
#               City     Sport Discipline           Event  \
# Year
# 1976.000  Montreal  Aquatics     Diving  3m springboard
# 1976.000  Montreal  Aquatics     Diving  3m springboard
# 1976.000  Montreal  Aquatics     Diving  3m springboard
# 1976.000  Montreal  Aquatics     Diving  3m springboard
# 1976.000  Montreal  Aquatics     Diving    10m platform
#
#                            Athlete Gender Country_Code        Country  \
# Year
# 1976.000           K�HLER, Christa  Women          GDR   East Germany
# 1976.000       KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 1976.000      BOGGS, Philip George    Men          USA  United States
# 1976.000  CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 1976.000    WILSON, Deborah Keplar  Women          USA  United States
#
#          Event_gender   Medal
# Year
# 1976.000            W  Silver
# 1976.000            M  Bronze
# 1976.000            M    Gold
# 1976.000            M  Silver
# ...

# %%
df.set_index('Year',inplace=True)

# %%
df.head()
# Out:
#             City     Sport Discipline           Event  \
# Year
# 1976.0  Montreal  Aquatics     Diving  3m springboard
# 1976.0  Montreal  Aquatics     Diving  3m springboard
# 1976.0  Montreal  Aquatics     Diving  3m springboard
# 1976.0  Montreal  Aquatics     Diving  3m springboard
# 1976.0  Montreal  Aquatics     Diving    10m platform
#
#                          Athlete Gender Country_Code        Country  \
# Year
# 1976.0           K�HLER, Christa  Women          GDR   East Germany
# 1976.0       KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 1976.0      BOGGS, Philip George    Men          USA  United States
# 1976.0  CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 1976.0    WILSON, Deborah Keplar  Women          USA  United States
#
#        Event_gender   Medal
# Year
# 1976.0            W  Silver
# 1976.0            M  Bronze
# 1976.0            M    Gold
# 1976.0            M  Silver
# 1976.0            W  Bronze

# %%
nombres = df['Athlete']
nombres
# Out:
# Year
# 1976.000             K�HLER, Christa
# 1976.000         KOSENKOV, Aleksandr
# 1976.000        BOGGS, Philip George
# 1976.000    CAGNOTTO, Giorgio Franco
# 1976.000      WILSON, Deborah Keplar
#                       ...
# 2008.000          GUENOT, Christophe
# 2008.000         KVIRKELIA, Manuchar
# 2008.000            RAHIMOV, Vitaliy
# 2008.000              GUENOT, Steeve
# 2008.000               LOPEZ, Mijain
# Name: Athlete, Length: 15433, dtype: object
