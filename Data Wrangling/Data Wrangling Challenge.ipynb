# %%
import numpy as np
import pandas as pd

# %%
#1. Leer la base de datos
dfP = pd.read_csv('C:/Users/camil/Desktop/k1000/Notebooks/Data Wrangling/p_data.csv', sep = ';')
dfW = pd.read_csv('C:/Users/camil/Desktop/k1000/Notebooks/Data Wrangling/w_data.csv', sep = ';')
dfP
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48837  33.0     Male   597186815                White   United-States
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
#
#         Education  Education-Num       Marital Status     Relationship
# ...

# %%
#2. Hacer merge de las dos bases de datos usando el id
df = pd.merge(dfP, dfW, on = 'ID')
df.set_index('ID')
df
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48837  33.0     Male   597186815                White   United-States
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
#
#         Education  Education-Num       Marital Status     Relationship  \
# ...

# %%
#3. Contar duplicados ////
df.groupby("ID").size().sort_values(ascending=False)
# Out:
# ID
# 3229272340    1
# 251683867     1
# 251950318     1
# 251945387     1
# 251925152     1
#              ..
# 783207722     1
# 783179636     1
# 783154385     1
# 782972524     1
# 3080          1
# Length: 48842, dtype: int64

# %%
#Target por sexo
targetBySex = pd.DataFrame(df, columns= ['Sex','Target']).value_counts()
targetBySex
# Out:
# Sex      Target
#  Male     <=50K     15128
#  Female   <=50K      9592
#  Male     <=50K.     7604
#           >50K       6662
#  Female   <=50K.     4831
#  Male     >50K.      3255
#  Female   >50K       1179
#           >50K.       590
# dtype: int64

# %%
#Target por etnia
targetByRace = pd.DataFrame(df, columns= ['Race','Target']).value_counts()
targetByRace
# Out:
# Race                 Target
#  White                <=50K     20699
#                       <=50K.    10456
#                       >50K       7117
#                       >50K.      3489
#  Black                <=50K      2737
#                       <=50K.     1382
#  Asian-Pac-Islander   <=50K       763
#  Black                >50K        387
#  Asian-Pac-Islander   <=50K.      347
#                       >50K        276
#  Amer-Indian-Eskimo   <=50K       275
#  Other                <=50K       246
#  Black                >50K.       179
#  Amer-Indian-Eskimo   <=50K.      140
#  Asian-Pac-Islander   >50K.       133
#  Other                <=50K.      110
#  Amer-Indian-Eskimo   >50K         36
#  Other                >50K         25
#                       >50K.        25
#  Amer-Indian-Eskimo   >50K.        19
# dtype: int64

# %%
#Target por nivel educativo
targetByEduc = pd.DataFrame(df, columns= ['Education','Target']).value_counts()
targetByEduc.head()
# Out:
# Education      Target
#  HS-grad        <=50K     8826
#  Some-college   <=50K     5904
#  HS-grad        <=50K.    4455
#  Bachelors      <=50K     3134
#  Some-college   <=50K.    2911
# dtype: int64
